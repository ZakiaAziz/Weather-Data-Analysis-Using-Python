# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 595

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}

url = "http://api.openweathermap.org/data/2.5/weather?"



# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    
        # Parse the JSON and retrieve data
    city_weather = requests.get(city_url+city).json()
  
    try:
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    #If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | wairoa
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | cabo san lucas
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | cherskiy
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | high prairie
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | north bend
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | campbellton
# Processing Record 16 of Set 1 | coihaique
# Processing Record 17 of Set 1 | esperance
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | sao filipe
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | ponta do sol
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | senaki
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | kalmunai
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | bac lieu
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | bonfim
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | ixtapa
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | chokurdakh
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 1 | mount gambier
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 1 | kushiro
# Processing Record 48 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 1 | ludza
# Processing Record 50 of Set 1 | torbay
# Processing Record 0 of Set 2 | kintinku
# Processing Record 1 of Set 2 | aklavik
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | namatanai
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | del rio
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | coquimbo
# Processing Record 11 of Set 2 | alugan
# Processing Record 12 of Set 2 | puerto colombia
# Processing Record 13 of Set 2 | beloha
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | dwarka
# Processing Record 16 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | salalah
# Processing Record 19 of Set 2 | dallas
# Processing Record 20 of Set 2 | jingdezhen
# Processing Record 21 of Set 2 | bindki
# Processing Record 22 of Set 2 | micheweni
# Processing Record 23 of Set 2 | waitara
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | ust-tsilma
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | leh
# Processing Record 28 of Set 2 | mimoso do sul
# Processing Record 29 of Set 2 | katsuura
# Processing Record 30 of Set 2 | lavrentiya
# Processing Record 31 of Set 2 | urucui
# Processing Record 32 of Set 2 | eureka
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | mukhen
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | kahului
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | kismayo
# Processing Record 40 of Set 2 | kaitangata
# Processing Record 41 of Set 2 | agadir
# Processing Record 42 of Set 2 | bethel
# Processing Record 43 of Set 2 | nagorsk
# Processing Record 44 of Set 2 | ranong
# Processing Record 45 of Set 2 | dikson
# Processing Record 46 of Set 2 | madaoua
# Processing Record 47 of Set 2 | leningradskiy
# Processing Record 48 of Set 2 | acarau
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 0 of Set 3 | kodiak
# Processing Record 1 of Set 3 | sinazongwe
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 | sri aman
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | lebedinyy
# Processing Record 8 of Set 3 | kachikau
# City not found. Skipping...
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | hamilton
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | caloundra
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 3 | severo-kurilsk
# Processing Record 18 of Set 3 | vung tau
# Processing Record 19 of Set 3 | crib point
# Processing Record 20 of Set 3 | revda
# Processing Record 21 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 3 | flinders
# Processing Record 23 of Set 3 | nikitinskiy
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | singaraja
# Processing Record 26 of Set 3 | meulaboh
# Processing Record 27 of Set 3 | te anau
# Processing Record 28 of Set 3 | ostrovnoy
# Processing Record 29 of Set 3 | bidor
# Processing Record 30 of Set 3 | znamenskoye
# Processing Record 31 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 3 | aripuana
# Processing Record 33 of Set 3 | lorengau
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | gobabis
# Processing Record 37 of Set 3 | ankang
# Processing Record 38 of Set 3 | serenje
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 3 | bandarbeyla
# Processing Record 42 of Set 3 | chilca
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | ilulissat
# Processing Record 45 of Set 3 | padang
# Processing Record 46 of Set 3 | nhulunbuy
# Processing Record 47 of Set 3 | buala
# Processing Record 48 of Set 3 | juba
# Processing Record 49 of Set 3 | jiayuguan
# Processing Record 0 of Set 4 | batemans bay
# Processing Record 1 of Set 4 | mount isa
# Processing Record 2 of Set 4 | tuatapere
# Processing Record 3 of Set 4 | bathsheba
# Processing Record 4 of Set 4 | urfa
# City not found. Skipping...
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | alta floresta
# Processing Record 7 of Set 4 | kemijarvi
# Processing Record 8 of Set 4 | aykhal
# Processing Record 9 of Set 4 | walvis bay
# Processing Record 10 of Set 4 | roald
# Processing Record 11 of Set 4 | brigantine
# Processing Record 12 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 13 of Set 4 | vila velha
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 4 | upernavik
# Processing Record 16 of Set 4 | hasaki
# Processing Record 17 of Set 4 | sao joao da barra
# Processing Record 18 of Set 4 | arlit
# Processing Record 19 of Set 4 | bartica
# Processing Record 20 of Set 4 | tamandare
# Processing Record 21 of Set 4 | athens
# Processing Record 22 of Set 4 | saint-pierre
# Processing Record 23 of Set 4 | bengkulu
# Processing Record 24 of Set 4 | mecca
# Processing Record 25 of Set 4 | lujan
# Processing Record 26 of Set 4 | biak
# Processing Record 27 of Set 4 | porto seguro
# Processing Record 28 of Set 4 | anshun
# Processing Record 29 of Set 4 | aden
# Processing Record 30 of Set 4 | bambanglipuro
# Processing Record 31 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 4 | cairns
# Processing Record 33 of Set 4 | kodinsk
# Processing Record 34 of Set 4 | bakel
# Processing Record 35 of Set 4 | pevek
# Processing Record 36 of Set 4 | musoma
# Processing Record 37 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 4 | olga
# Processing Record 39 of Set 4 | gondanglegi
# Processing Record 40 of Set 4 | margate
# Processing Record 41 of Set 4 | talnakh
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | fortuna
# Processing Record 44 of Set 4 | tomatlan
# Processing Record 45 of Set 4 | kavaratti
# Processing Record 46 of Set 4 | ancud
# Processing Record 47 of Set 4 | eyl
# Processing Record 48 of Set 4 | barentu
# Processing Record 49 of Set 4 | takehara
# Processing Record 0 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 1 of Set 5 | severnyy
# Processing Record 2 of Set 5 | balakhta
# Processing Record 3 of Set 5 | lendava
# Processing Record 4 of Set 5 | khatanga
# Processing Record 5 of Set 5 | beyneu
# Processing Record 6 of Set 5 | omboue
# Processing Record 7 of Set 5 | gamba
# Processing Record 8 of Set 5 | belmonte
# Processing Record 9 of Set 5 | sioux lookout
# Processing Record 10 of Set 5 | smithers
# Processing Record 11 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 5 | asyut
# Processing Record 13 of Set 5 | aksha
# Processing Record 14 of Set 5 | geraldton
# Processing Record 15 of Set 5 | tiznit
# Processing Record 16 of Set 5 | sambava
# Processing Record 17 of Set 5 | yatou
# Processing Record 18 of Set 5 | doha
# Processing Record 19 of Set 5 | kruisfontein
# Processing Record 20 of Set 5 | a
# City not found. Skipping...
# Processing Record 21 of Set 5 | martinis
# Processing Record 22 of Set 5 | gimli
# Processing Record 23 of Set 5 | hofn
# Processing Record 24 of Set 5 | qaqortoq
# Processing Record 25 of Set 5 | bugulma
# Processing Record 26 of Set 5 | ndele
# Processing Record 27 of Set 5 | victoria
# Processing Record 28 of Set 5 | ambatondrazaka
# Processing Record 29 of Set 5 | qena
# Processing Record 30 of Set 5 | pacific grove
# Processing Record 31 of Set 5 | longyearbyen
# Processing Record 32 of Set 5 | hohhot
# Processing Record 33 of Set 5 | shakiso
# Processing Record 34 of Set 5 | carnarvon
# Processing Record 35 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 5 | hay river
# Processing Record 37 of Set 5 | dingle
# Processing Record 38 of Set 5 | zhuhai
# Processing Record 39 of Set 5 | marzuq
# Processing Record 40 of Set 5 | ha tinh
# Processing Record 41 of Set 5 | sisimiut
# Processing Record 42 of Set 5 | anadyr
# Processing Record 43 of Set 5 | faya
# Processing Record 44 of Set 5 | bilma
# Processing Record 45 of Set 5 | raga
# Processing Record 46 of Set 5 | vaovai
# City not found. Skipping...
# Processing Record 47 of Set 5 | colares
# Processing Record 48 of Set 5 | vao
# Processing Record 49 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 0 of Set 6 | karlstad
# Processing Record 1 of Set 6 | san cristobal
# Processing Record 2 of Set 6 | glendive
# Processing Record 3 of Set 6 | teeli
# Processing Record 4 of Set 6 | buchanan
# Processing Record 5 of Set 6 | namibe
# Processing Record 6 of Set 6 | puerto carreno
# Processing Record 7 of Set 6 | avera
# Processing Record 8 of Set 6 | concordia
# Processing Record 9 of Set 6 | katherine
# Processing Record 10 of Set 6 | naze
# Processing Record 11 of Set 6 | kondagaon
# Processing Record 12 of Set 6 | hanko
# Processing Record 13 of Set 6 | antalaha
# Processing Record 14 of Set 6 | lagoa
# Processing Record 15 of Set 6 | gazanjyk
# Processing Record 16 of Set 6 | vardo
# Processing Record 17 of Set 6 | cockburn town
# Processing Record 18 of Set 6 | isangel
# Processing Record 19 of Set 6 | buon me thuot
# City not found. Skipping...
# Processing Record 20 of Set 6 | santiago
# Processing Record 21 of Set 6 | narsaq
# Processing Record 22 of Set 6 | straumen
# Processing Record 23 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 6 | coswig
# Processing Record 25 of Set 6 | leon
# Processing Record 26 of Set 6 | nivala
# Processing Record 27 of Set 6 | guerrero negro
# Processing Record 28 of Set 6 | quelimane
# Processing Record 29 of Set 6 | la plata
# Processing Record 30 of Set 6 | srednekolymsk
# Processing Record 31 of Set 6 | asosa
# Processing Record 32 of Set 6 | washougal
# Processing Record 33 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 6 | bima
# Processing Record 35 of Set 6 | chapulhuacan
# Processing Record 36 of Set 6 | kokoda
# Processing Record 37 of Set 6 | port macquarie
# Processing Record 38 of Set 6 | parit buntar
# Processing Record 39 of Set 6 | pisco
# Processing Record 40 of Set 6 | sechura
# Processing Record 41 of Set 6 | grand gaube
# Processing Record 42 of Set 6 | bilibino
# Processing Record 43 of Set 6 | nanortalik
# Processing Record 44 of Set 6 | masuguru
# Processing Record 45 of Set 6 | namie
# Processing Record 46 of Set 6 | luganville
# Processing Record 47 of Set 6 | siwani
# City not found. Skipping...
# Processing Record 48 of Set 6 | kupang
# Processing Record 49 of Set 6 | ribeira grande
# Processing Record 0 of Set 7 | kuandian
# Processing Record 1 of Set 7 | san andres
# Processing Record 2 of Set 7 | sitio novo do tocantins
# Processing Record 3 of Set 7 | salinopolis
# Processing Record 4 of Set 7 | estepa
# Processing Record 5 of Set 7 | port hardy
# Processing Record 6 of Set 7 | saint george
# Processing Record 7 of Set 7 | lompoc
# Processing Record 8 of Set 7 | krasnorechenskiy
# Processing Record 9 of Set 7 | sao felix do xingu
# Processing Record 10 of Set 7 | senneterre
# Processing Record 11 of Set 7 | chanika
# Processing Record 12 of Set 7 | prince rupert
# Processing Record 13 of Set 7 | kenai
# Processing Record 14 of Set 7 | shelabolikha
# Processing Record 15 of Set 7 | brownsville
# Processing Record 16 of Set 7 | labuhan
# Processing Record 17 of Set 7 | tura
# Processing Record 18 of Set 7 | imbituba
# Processing Record 19 of Set 7 | chokwe
# Processing Record 20 of Set 7 | tianpeng
# Processing Record 21 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 22 of Set 7 | sept-iles
# Processing Record 23 of Set 7 | araouane
# Processing Record 24 of Set 7 | iqaluit
# Processing Record 25 of Set 7 | gallup
# Processing Record 26 of Set 7 | bull savanna
# Processing Record 27 of Set 7 | salym
# Processing Record 28 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 7 | yelizovo
# Processing Record 30 of Set 7 | novospasskoye
# Processing Record 31 of Set 7 | shizunai
# Processing Record 32 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 7 | deshna
# City not found. Skipping...
# Processing Record 34 of Set 7 | springfield
# Processing Record 35 of Set 7 | pemba
# Processing Record 36 of Set 7 | nome
# Processing Record 37 of Set 7 | svetlyy
# Processing Record 38 of Set 7 | kedrovyy
# Processing Record 39 of Set 7 | andenes
# Processing Record 40 of Set 7 | portland
# Processing Record 41 of Set 7 | zalaszentgrot
# Processing Record 42 of Set 7 | fairview
# Processing Record 43 of Set 7 | sur
# Processing Record 44 of Set 7 | osakarovka
# Processing Record 45 of Set 7 | tual
# Processing Record 46 of Set 7 | shingu
# Processing Record 47 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 7 | broome
# Processing Record 49 of Set 7 | lasa
# Processing Record 0 of Set 8 | broken hill
# Processing Record 1 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 8 | yumen
# Processing Record 3 of Set 8 | porto novo
# Processing Record 4 of Set 8 | vidim
# Processing Record 5 of Set 8 | umtata
# Processing Record 6 of Set 8 | odweyne
# Processing Record 7 of Set 8 | lafia
# Processing Record 8 of Set 8 | xining
# Processing Record 9 of Set 8 | nemuro
# Processing Record 10 of Set 8 | monreal
# Processing Record 11 of Set 8 | rio de janeiro
# Processing Record 12 of Set 8 | dawson
# Processing Record 13 of Set 8 | lulea
# Processing Record 14 of Set 8 | vostok
# Processing Record 15 of Set 8 | high level
# Processing Record 16 of Set 8 | krasnoselkup
# Processing Record 17 of Set 8 | mangla
# Processing Record 18 of Set 8 | iracoubo
# Processing Record 19 of Set 8 | monticello
# Processing Record 20 of Set 8 | akdepe
# Processing Record 21 of Set 8 | hefei
# Processing Record 22 of Set 8 | la romana
# Processing Record 23 of Set 8 | komsomolskiy
# Processing Record 24 of Set 8 | faanui
# Processing Record 25 of Set 8 | kambove
# Processing Record 26 of Set 8 | verkhnevilyuysk
# Processing Record 27 of Set 8 | kailua
# Processing Record 28 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 8 | senanga
# Processing Record 30 of Set 8 | staro nagoricane
# City not found. Skipping...
# Processing Record 31 of Set 8 | manokwari
# Processing Record 32 of Set 8 | half moon bay
# Processing Record 33 of Set 8 | marienburg
# Processing Record 34 of Set 8 | caohe
# Processing Record 35 of Set 8 | bosobolo
# Processing Record 36 of Set 8 | mwinilunga
# Processing Record 37 of Set 8 | honningsvag
# Processing Record 38 of Set 8 | voh
# Processing Record 39 of Set 8 | kungurtug
# Processing Record 40 of Set 8 | bahia blanca
# Processing Record 41 of Set 8 | sao jose de piranhas
# Processing Record 42 of Set 8 | outjo
# Processing Record 43 of Set 8 | ambon
# Processing Record 44 of Set 8 | waddan
# Processing Record 45 of Set 8 | sorong
# Processing Record 46 of Set 8 | emborion
# Processing Record 47 of Set 8 | alofi
# Processing Record 48 of Set 8 | rantepao
# Processing Record 49 of Set 8 | ransang
# Processing Record 0 of Set 9 | jackson
# Processing Record 1 of Set 9 | sudak
# Processing Record 2 of Set 9 | mandalgovi
# Processing Record 3 of Set 9 | massakory
# Processing Record 4 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 5 of Set 9 | zhangye
# Processing Record 6 of Set 9 | marsh harbour
# Processing Record 7 of Set 9 | kaeo
# Processing Record 8 of Set 9 | rabo de peixe
# Processing Record 9 of Set 9 | letlhakane
# Processing Record 10 of Set 9 | iquique
# Processing Record 11 of Set 9 | henties bay
# Processing Record 12 of Set 9 | selimpasa
# Processing Record 13 of Set 9 | valparaiso
# Processing Record 14 of Set 9 | humaita
# Processing Record 15 of Set 9 | borujan
# City not found. Skipping...
# Processing Record 16 of Set 9 | san patricio
# Processing Record 17 of Set 9 | svetlogorsk
# Processing Record 18 of Set 9 | nagapattinam
# Processing Record 19 of Set 9 | harlingen
# Processing Record 20 of Set 9 | roma
# Processing Record 21 of Set 9 | san juan de opoa
# Processing Record 22 of Set 9 | saldanha
# Processing Record 23 of Set 9 | boden
# Processing Record 24 of Set 9 | maputo
# Processing Record 25 of Set 9 | asau
# Processing Record 26 of Set 9 | neka
# Processing Record 27 of Set 9 | chaman
# Processing Record 28 of Set 9 | fort nelson
# Processing Record 29 of Set 9 | pangnirtung
# Processing Record 30 of Set 9 | nikel
# Processing Record 31 of Set 9 | derzhavinsk
# Processing Record 32 of Set 9 | peace river
# Processing Record 33 of Set 9 | the valley
# Processing Record 34 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 35 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 36 of Set 9 | langenburg
# Processing Record 37 of Set 9 | aklera
# Processing Record 38 of Set 9 | najran
# Processing Record 39 of Set 9 | arboletes
# Processing Record 40 of Set 9 | port saint john
# Processing Record 41 of Set 9 | sabang
# Processing Record 42 of Set 9 | moussoro
# Processing Record 43 of Set 9 | rakhya
# City not found. Skipping...
# Processing Record 44 of Set 9 | nandurbar
# Processing Record 45 of Set 9 | jining
# Processing Record 46 of Set 9 | panjab
# Processing Record 47 of Set 9 | mattawa
# Processing Record 48 of Set 9 | tilichiki
# Processing Record 49 of Set 9 | piacabucu
# Processing Record 0 of Set 10 | tokat
# Processing Record 1 of Set 10 | itupiranga
# Processing Record 2 of Set 10 | carutapera
# Processing Record 3 of Set 10 | russell
# Processing Record 4 of Set 10 | vila franca do campo
# Processing Record 5 of Set 10 | lastoursville
# Processing Record 6 of Set 10 | siwan
# Processing Record 7 of Set 10 | camacha
# Processing Record 8 of Set 10 | qasigiannguit
# Processing Record 9 of Set 10 | kargasok
# Processing Record 10 of Set 10 | praia da vitoria
# Processing Record 11 of Set 10 | sao jose da coroa grande
# Processing Record 12 of Set 10 | itarema
# Processing Record 13 of Set 10 | warwick
# Processing Record 14 of Set 10 | abu samrah
# Processing Record 15 of Set 10 | cap malheureux
# Processing Record 16 of Set 10 | tonkino
# Processing Record 17 of Set 10 | cayenne
# Processing Record 18 of Set 10 | koscian
# Processing Record 19 of Set 10 | severnyy-kospashskiy
# Processing Record 20 of Set 10 | chara
# Processing Record 21 of Set 10 | gao
# Processing Record 22 of Set 10 | pa daet
# Processing Record 23 of Set 10 | dunedin
# Processing Record 24 of Set 10 | orlik
# Processing Record 25 of Set 10 | sakakah
# Processing Record 26 of Set 10 | nador
# Processing Record 27 of Set 10 | linqiong
# Processing Record 28 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 29 of Set 10 | soto la marina
# Processing Record 30 of Set 10 | tazovskiy
# Processing Record 31 of Set 10 | deputatskiy
# Processing Record 32 of Set 10 | rio gallegos
# Processing Record 33 of Set 10 | pong
# Processing Record 34 of Set 10 | saint-augustin
# Processing Record 35 of Set 10 | klaksvik
# Processing Record 36 of Set 10 | saint anthony
# Processing Record 37 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 38 of Set 10 | fomboni
# Processing Record 39 of Set 10 | lata
# Processing Record 40 of Set 10 | nha trang
# Processing Record 41 of Set 10 | havre-saint-pierre
# Processing Record 42 of Set 10 | sola
# Processing Record 43 of Set 10 | payo
# Processing Record 44 of Set 10 | portales
# Processing Record 45 of Set 10 | mareeba
# Processing Record 46 of Set 10 | lokosovo
# Processing Record 47 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 48 of Set 10 | yulara
# Processing Record 49 of Set 10 | novodzherelievskaya
# City not found. Skipping...
# Processing Record 0 of Set 11 | kruszwica
# Processing Record 1 of Set 11 | lakota
# Processing Record 2 of Set 11 | plastun
# Processing Record 3 of Set 11 | daura
# Processing Record 4 of Set 11 | los llanos de aridane
# Processing Record 5 of Set 11 | arrifes
# Processing Record 6 of Set 11 | harur
# Processing Record 7 of Set 11 | guerande
# Processing Record 8 of Set 11 | la ronge
# Processing Record 9 of Set 11 | rodrigues alves
# Processing Record 10 of Set 11 | ust-kuyga
# Processing Record 11 of Set 11 | estrela
# Processing Record 12 of Set 11 | wagga wagga
# Processing Record 13 of Set 11 | neyshabur
# Processing Record 14 of Set 11 | cuiluan
# Processing Record 15 of Set 11 | porto murtinho
# Processing Record 16 of Set 11 | loa janan
# Processing Record 17 of Set 11 | chernyshevskiy
# Processing Record 18 of Set 11 | belyy yar
# Processing Record 19 of Set 11 | bagan
# Processing Record 20 of Set 11 | turiacu
# Processing Record 21 of Set 11 | revelstoke
# Processing Record 22 of Set 11 | tateyama
# Processing Record 23 of Set 11 | inuvik
# Processing Record 24 of Set 11 | fare
# Processing Record 25 of Set 11 | kenora
# Processing Record 26 of Set 11 | gazli
# Processing Record 27 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 11 | moindou
# Processing Record 29 of Set 11 | minab
# Processing Record 30 of Set 11 | kalinovskoye
# Processing Record 31 of Set 11 | rocha
# Processing Record 32 of Set 11 | sape
# Processing Record 33 of Set 11 | illapel
# Processing Record 34 of Set 11 | okha
# Processing Record 35 of Set 11 | marsa matruh
# Processing Record 36 of Set 11 | krasnaya gorka
# Processing Record 37 of Set 11 | mlimba
# Processing Record 38 of Set 11 | praya
# Processing Record 39 of Set 11 | kawhia
# Processing Record 40 of Set 11 | kabo
# Processing Record 41 of Set 11 | omsukchan
# Processing Record 42 of Set 11 | ushumun
# Processing Record 43 of Set 11 | natal
# Processing Record 44 of Set 11 | alice town
# Processing Record 45 of Set 11 | panino
# Processing Record 46 of Set 11 | maraba
# Processing Record 47 of Set 11 | acapulco
# Processing Record 48 of Set 11 | puerto del rosario
# Processing Record 49 of Set 11 | marataizes
# Processing Record 0 of Set 12 | nyaunglebin
# Processing Record 1 of Set 12 | mogadishu
# Processing Record 2 of Set 12 | hailey
# Processing Record 3 of Set 12 | burnie
# Processing Record 4 of Set 12 | ajdabiya
# Processing Record 5 of Set 12 | bacolod
# Processing Record 6 of Set 12 | kharabali
# Processing Record 7 of Set 12 | kananga
# Processing Record 8 of Set 12 | olpad
# Processing Record 9 of Set 12 | zhigansk
# Processing Record 10 of Set 12 | haines junction
# Processing Record 11 of Set 12 | chubbuck
# Processing Record 12 of Set 12 | badiraguato
# Processing Record 13 of Set 12 | sal rei
# Processing Record 14 of Set 12 | yarada
# Processing Record 15 of Set 12 | madang
# Processing Record 16 of Set 12 | husavik
# Processing Record 17 of Set 12 | tagusao
# Processing Record 18 of Set 12 | male
# Processing Record 19 of Set 12 | sainte-suzanne
# Processing Record 20 of Set 12 | san quintin
# Processing Record 21 of Set 12 | igarka
# Processing Record 22 of Set 12 | santa cruz
# Processing Record 23 of Set 12 | virginia beach
# Processing Record 24 of Set 12 | escarcega
# Processing Record 25 of Set 12 | tonj
# Processing Record 26 of Set 12 | grindavik
# Processing Record 27 of Set 12 | kaniama
# Processing Record 28 of Set 12 | emerald
# Processing Record 29 of Set 12 | handan
# Processing Record 30 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 12 | constitucion
# Processing Record 32 of Set 12 | fairbanks
# Processing Record 33 of Set 12 | rosetta
# Processing Record 34 of Set 12 | paita
# Processing Record 35 of Set 12 | hovd
# Processing Record 36 of Set 12 | den helder
# Processing Record 37 of Set 12 | todos santos
# Processing Record 38 of Set 12 | kaduy
# Processing Record 39 of Set 12 | ucluelet
# Processing Record 40 of Set 12 | grand-santi
# Processing Record 41 of Set 12 | oistins
# Processing Record 42 of Set 12 | tessalit
# Processing Record 43 of Set 12 | kulhudhuffushi
# Processing Record 44 of Set 12 | zarate
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df= pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          546
# Lat           546
# Lng           546
# Max Temp      546
# Humidity      546
# Cloudiness    546
# Wind Speed    546
# Country       546
# Date          546
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          wairoa -39.0333  177.3667    291.23        99         100
# 1      georgetown   5.4112  100.3354    298.12        87          20
# 2      butaritari   3.0707  172.7902    300.30        78          89
# 3  cabo san lucas  22.8909 -109.9124    295.32        64          20
# 4      bredasdorp -34.5322   20.0403    293.15        84           6
#
#    Wind Speed Country        Date
# 0        3.13      NZ  1674088629
# 1        2.06      MY  1674088507
# 2        7.09      KI  1674088631
# 3        4.63      MX  1674088631
# 4        2.61      ZA  1674088632

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                wairoa -39.0333  177.3667    291.23        99         100
# 1            georgetown   5.4112  100.3354    298.12        87          20
# 2            butaritari   3.0707  172.7902    300.30        78          89
# 3        cabo san lucas  22.8909 -109.9124    295.32        64          20
# 4            bredasdorp -34.5322   20.0403    293.15        84           6
#
#          Wind Speed Country        Date
# City_ID
# 0              3.13      NZ  1674088629
# 1              2.06      MY  1674088507
# 2              7.09      KI  1674088631
# 3              4.63      MX  1674088631
# 4              2.61      ZA  1674088632

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

plt.plot(city_data_df["Lat"],city_data_df["Max Temp"],"o", mec= 'k')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title('City Max Latitude vs. Temperature(2022-10-18)')
plt.grid()


# Incorporate the other graph properties


# Save the figure
plt.savefig("output_data/Fig1.png")

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
plt.plot(city_data_df["Lat"],city_data_df["Humidity"],"o", mec= 'k')
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Max Latitude vs. Humidity(2022-10-18)')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
plt.plot(city_data_df["Lat"],city_data_df["Cloudiness"],"o", mec= 'k')
plt.xlabel('Latitude')
plt.ylabel('Cloudliness(%)')
plt.title('City Max Latitude vs. Cloudliness(2022-10-18)')
plt.grid()




# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.plot(city_data_df["Lat"],city_data_df["Wind Speed"],"o", mec= 'k')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
plt.title('City Max Latitude vs. Cloudliness(2022-10-18)')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = pd.DataFrame(city_data_df.loc[city_data_df['Lat']>=0,:])

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            georgetown   5.4112  100.3354    298.12        87          20
# 2            butaritari   3.0707  172.7902    300.30        78          89
# 3        cabo san lucas  22.8909 -109.9124    295.32        64          20
# 7              cherskiy  68.7500  161.3000    230.64        99         100
# 8          high prairie  55.4334 -116.4858    262.60        95          92
#
#          Wind Speed Country        Date
# City_ID
# 1              2.06      MY  1674088507
# 2              7.09      KI  1674088631
# 3              4.63      MX  1674088631
# 7              1.83      RU  1674088636
# 8              1.10      CA  1674088637

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = pd.DataFrame(city_data_df.loc[city_data_df['Lat']<0,:])

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             wairoa -39.0333  177.3667    291.23        99         100
# 4         bredasdorp -34.5322   20.0403    293.15        84           6
# 5              airai  -8.9266  125.4092    293.29        77         100
# 6             hobart -42.8794  147.3294    289.41        47          40
# 9        port alfred -33.5906   26.8910    296.58        85         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.13      NZ  1674088629
# 4              2.61      ZA  1674088632
# 5              1.41      TL  1674088378
# 6              6.69      AU  1674088635
# 9              1.79      ZA  1674088638

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.annotate(line_eq,(0,240),fontsize=20,color="red")
plt.show()
# Out:
# The r-value is: -0.8411735002137372

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.annotate(line_eq,(-50,305),fontsize=20,color="red")
plt.show()
# Out:
# The r-value is: 0.35663619190968404

# %% [markdown]
# **Discussion about the linear relationship:** In Northern Hemisphere the r value is close to -1, which implies Temperature and Latitude are negatively related. As the Latitude gets higher Temperature gets lower.
# In Southern Hemisphere, the r value is 0.35, which does not indicates weak positive relationship between the Latitude and Temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.annotate(line_eq,(40,20),fontsize=20,color="red")
plt.show()
# Out:
# The r-value is: 0.4659153751660786

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.annotate(line_eq,(-30,50),fontsize=20,color="red")
plt.show()
# Out:
# The r-value is: 0.47705456119373224

# %% [markdown]
# **Discussion about the linear relationship:** In Northern Hempisphere, the r value is 0.46, which implies the Latitude and Humidity have moderate positive relationship.
# In Southern Hemisphere, the r value is 0.47, which is also close to 0.5 which means latitude and humdity have moderate positive relationship. In, conclusion, it can be said Humdity increases with latitude increase.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.annotate(line_eq,(40,20),fontsize=20,color="red")
plt.show()
# Out:
# The r-value is: 0.34008778258203537

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.annotate(line_eq,(-30,20),fontsize=20,color="red")
plt.show()
# Out:
# The r-value is: 0.43920979446403474

# %% [markdown]
# **Discussion about the linear relationship:** In Northern and Southern both Hemispheres, r value is between 0.3 to 0.5, which implies, Latitude and Cloudiness have weak positive relationship.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.annotate(line_eq,(30,12),fontsize=20,color="red")
plt.show()
# Out:
# The r-value is: 0.019331549996941245

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.annotate(line_eq,(-30,12),fontsize=20,color="red")
plt.show()
# Out:
# The r-value is: -0.25573524355189703

# %% [markdown]
# **Discussion about the linear relationship:** In Northern Hemisphere, r value is almost 0, which indicates there is no relationship between Latitude and Wind Speed. In Southern Hemipshere, r value is also less than 0.3, that implies, there is no relationship between Latitude and Wind Speed.
